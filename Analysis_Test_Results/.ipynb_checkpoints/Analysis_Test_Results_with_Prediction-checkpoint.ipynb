# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import csv
from collections import OrderedDict
from update_dataframe import *
from matplotlib import cbook
import seaborn as sns
import math

# %%
# #creating a new dataframe

# columns = [['Date','Total_Sent','Sent_On_Date','Proceed_In_24_Hr','Total_Positive','New_Positive']]
# test_report = pd.DataFrame(columns=columns)
# test_report.to_csv('data/Analysis_Test_Results.csv')

# %%
test_report = pd.read_csv('data/Analysis_Test_Results.csv')
del test_report['Unnamed: 0']
test_report
# Out:
#           Date  Total_Sent  Sent_On_Date  Proceed_In_24_Hr  Total_Positive  \
# 0   04/08/2020      858960         24745             20087           27956
# 1   05/08/2020      884056         25096             25096           29151
# 2   06/08/2020      908355         24299             25205           30449
# 3   07/08/2020      936651         28296             27608           31700
# 4   08/08/2020      963632         26981             27714           33120
# ..         ...         ...           ...               ...             ...
# 60  03/10/2020     3104878         55087             54563          221333
# 61  04/10/2020     3164072         59194             58727          229886
# 62  05/10/2020     3198423         34351             38696          234928
# 63  06/10/2020     3263691         65268             60494          242799
# 64  07/10/2020     3340242         76551             73816          253405
#
#     New_Positive
# 0           1083
# 1           1195
# 2           1298
# 3           1251
# 4           1420
# ..           ...
# 60          7834
# 61          8553
# 62          5042
# 63          7871
# 64         10606
#
# [65 rows x 6 columns]

# %%
file_path = 'data/Analysis_Test_Results.csv'
#update_file(test_report,file_path)

# %%
#check if there is unwanterd columns ?
print(test_report.columns)
inp = input("is there any unwanted coumns ? (y/n)")
if inp == 'y':
    check = input('Is column name is Unnamed: 0 (y/n)')
    if check == 'y':
        del test_report['Unnamed: 0']
        print('deleted')
    else :
        column_name =  input("Enter column name :")
        del test_report[column_name]
        print('deleted')
test_report.to_csv(file_path, index = True)
# Out:
# Index(['Date', 'Total_Sent', 'Sent_On_Date', 'Proceed_In_24_Hr',
#        'Total_Positive', 'New_Positive'],
#       dtype='object')
# is there any unwanted coumns ? (y/n)n

# %%
update_file(test_report,file_path)
# Out:
# Do you have to update the data  : (y/n)y
# <class 'str'>
# hi
#  Options !!
# 	Add Column : c
# 	Add row values : r
# Enter your optionr
# -------------------
# Adding row values
# -------------------
# Enter Date 08/10/2020
# Enter Total_Sent 3402903
# Enter Sent_On_Date 62661
# Enter Proceed_In_24_Hr 62661
# Enter Total_Positive 258850
# Enter New_Positive 5445
#           Date  Total_Sent  Sent_On_Date  Proceed_In_24_Hr  Total_Positive  \
# 0   04/08/2020      858960         24745             20087           27956
# 1   05/08/2020      884056         25096             25096           29151
# 2   06/08/2020      908355         24299             25205           30449
# 3   07/08/2020      936651         28296             27608           31700
# 4   08/08/2020      963632         26981             27714           33120
# ..         ...         ...           ...               ...             ...
# 61  04/10/2020     3164072         59194             58727          229886
# 62  05/10/2020     3198423         34351             38696          234928
# 63  06/10/2020     3263691         65268             60494          242799
# 64  07/10/2020     3340242         76551             73816          253405
# 65  08/10/2020     3402903         62661             62661          258850
#
#     New_Positive
# 0           1083
# 1           1195
# 2           1298
# 3           1251
# 4           1420
# ..           ...
# 61          8553
# 62          5042
# 63          7871
# 64         10606
# 65          5445
#
# [66 rows x 6 columns]
# Do you want to save these changes (y/n): y
#           Date  Total_Sent  Sent_On_Date  Proceed_In_24_Hr  Total_Positive  \
# 0   04/08/2020      858960         24745             20087           27956
# 1   05/08/2020      884056         25096             25096           29151
# 2   06/08/2020      908355         24299             25205           30449
# 3   07/08/2020      936651         28296             27608           31700
# 4   08/08/2020      963632         26981             27714           33120
# ..         ...         ...           ...               ...             ...
# 61  04/10/2020     3164072         59194             58727          229886
# 62  05/10/2020     3198423         34351             38696          234928
# 63  06/10/2020     3263691         65268             60494          242799
# 64  07/10/2020     3340242         76551             73816          253405
# 65  08/10/2020     3402903         62661             62661          258850
#
#     New_Positive
# 0           1083
# 1           1195
# 2           1298
# 3           1251
# 4           1420
# ..           ...
# 61          8553
# 62          5042
# 63          7871
# 64         10606
# 65          5445
#
# [66 rows x 6 columns]
# do you want to add more : (y/n)n
# Final :
#           Date  Total_Sent  Sent_On_Date  Proceed_In_24_Hr  Total_Positive  \
# 0   04/08/2020      858960         24745             20087           27956
# 1   05/08/2020      884056         25096             25096           29151
# 2   06/08/2020      908355         24299             25205           30449
# 3   07/08/2020      936651         28296             27608           31700
# 4   08/08/2020      963632         26981             27714           33120
# ..         ...         ...           ...               ...             ...
# 61  04/10/2020     3164072         59194             58727          229886
# 62  05/10/2020     3198423         34351             38696          234928
# 63  06/10/2020     3263691         65268             60494          242799
# 64  07/10/2020     3340242         76551             73816          253405
# 65  08/10/2020     3402903         62661             62661          258850
#
#     New_Positive
# 0           1083
# 1           1195
# 2           1298
# 3           1251
# 4           1420
# ..           ...
# 61          8553
# 62          5042
# 63          7871
# 64         10606
# 65          5445
#
# [66 rows x 6 columns]
# Do you want to overwrite csv file : (y/n) y
# Successully saved data

# %%
test_report = pd.read_csv('data/Analysis_Test_Results.csv')
del test_report['Unnamed: 0']
test_report
# Out:
#           Date  Total_Sent  Sent_On_Date  Proceed_In_24_Hr  Total_Positive  \
# 0   04/08/2020      858960         24745             20087           27956
# 1   05/08/2020      884056         25096             25096           29151
# 2   06/08/2020      908355         24299             25205           30449
# 3   07/08/2020      936651         28296             27608           31700
# 4   08/08/2020      963632         26981             27714           33120
# ..         ...         ...           ...               ...             ...
# 61  04/10/2020     3164072         59194             58727          229886
# 62  05/10/2020     3198423         34351             38696          234928
# 63  06/10/2020     3263691         65268             60494          242799
# 64  07/10/2020     3340242         76551             73816          253405
# 65  08/10/2020     3402903         62661             62661          258850
#
#     New_Positive
# 0           1083
# 1           1195
# 2           1298
# 3           1251
# 4           1420
# ..           ...
# 61          8553
# 62          5042
# 63          7871
# 64         10606
# 65          5445
#
# [66 rows x 6 columns]

# %%
fig = plt.figure(figsize=(15,8))
plt.plot(test_report['Date'],test_report['Total_Positive'],'-*',color='darkblue',linewidth=3, markersize=9)
plt.xticks(rotation=55,ha='right')
plt.xlabel('Date',fontsize='large')
plt.ylabel('Test positive',fontsize='large')
plt.title(' Case study : Total positive ',fontsize='x-large')
#plt.grid(True)
fig.savefig('results/Total_Positive.png')

# %%
fig = plt.figure(figsize=(15,8))
plt.plot(test_report['Date'],test_report['Proceed_In_24_Hr'],'-o',color='#FF4500',linewidth=3, markersize=9)
plt.xticks(rotation=55,ha='right')
plt.xlabel('Date',fontsize='large')
plt.ylabel('test samples',fontsize='large')
plt.title(' Case study : Processed witin 24 hours ',fontsize='x-large')
#plt.grid(True)
fig.savefig('results/Proceedin24.png')

# %%
fig = plt.figure(figsize=(15,8))
plt.plot(test_report['Date'],test_report['Sent_On_Date'],'--',color='#808000',linewidth=3, markersize=9)
plt.xticks(rotation=55,ha='right')
plt.xlabel('Date',fontsize='large')
plt.ylabel('Test samples',fontsize='large')
plt.title(' Case study : Sent on Date ',fontsize='x-large')
#plt.grid(True)
fig.savefig('results/sentondate.png')

# %% [markdown]
# ## Trying to train the data

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
features = test_report[['Total_Sent', 'Sent_On_Date', 'Proceed_In_24_Hr', 'Total_Positive']]
label = test_report[['New_Positive']]

# %%
features
# Out:
#     Total_Sent  Sent_On_Date  Proceed_In_24_Hr  Total_Positive
# 0       858960         24745             20087           27956
# 1       884056         25096             25096           29151
# 2       908355         24299             25205           30449
# 3       936651         28296             27608           31700
# 4       963632         26981             27714           33120
# ..         ...           ...               ...             ...
# 61     3164072         59194             58727          229886
# 62     3198423         34351             38696          234928
# 63     3263691         65268             60494          242799
# 64     3340242         76551             73816          253405
# 65     3402903         62661             62661          258850
#
# [66 rows x 4 columns]

# %%
label
# Out:
#     New_Positive
# 0           1083
# 1           1195
# 2           1298
# 3           1251
# 4           1420
# ..           ...
# 61          8553
# 62          5042
# 63          7871
# 64         10606
# 65          5445
#
# [66 rows x 1 columns]

# %% [markdown]
# ## Finding the important features

# %%
import rfpimp
from sklearn.ensemble import RandomForestRegressor
# Out:
# C:\Users\Shoukkiya_Ashraf\miniconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.ensemble.forest module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
x_train,x_test,y_train,y_test = train_test_split(features,label,test_size = 0.3,random_state=42)

# %%
rf = RandomForestRegressor(n_estimators=100,n_jobs=-1)
rf.fit(x_train,y_train)
# Out:
# C:\Users\Shoukkiya_Ashraf\miniconda3\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=-1, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
imp = rfpimp.importances(rf,x_test,y_test)

# %%
fig,ax = plt.subplots(figsize=(10,5))
ax.barh(imp.index,imp['Importance'],height=0.8,alpha=0.8)
ax.set_xlabel('Importance score')
ax.set_title('Permutation feature importance')
plt.gca().invert_yaxis()
fig.tight_layout()

# %%
model = LinearRegression()
model.fit(features,label)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
import statsmodels.formula.api as sm
model_multi = sm.ols('New_Positive ~ Total_Sent + Sent_On_Date + Proceed_In_24_Hr',test_report).fit()
print(model_multi.params)
# Out:
# Intercept          -3244.612686
# Total_Sent             0.001351
# Sent_On_Date          -0.004242
# Proceed_In_24_Hr       0.112355
# dtype: float64

# %%
# Create a correlation matrix
corr_metrics = test_report.corr()
corr_metrics.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row0_col0,#T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row1_col1,#T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row2_col2,#T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row3_col3,#T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row4_col4{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row0_col1,#T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row0_col2,#T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row1_col0,#T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row1_col3,#T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row1_col4{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row0_col3{
#             background-color:  #04598c;
#             color:  #f1f1f1;
#         }#T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row0_col4{
#             background-color:  #9ebad9;
#             color:  #000000;
#         }#T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row1_col2{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row2_col0{
#             background-color:  #b5c4df;
#             color:  #000000;
#         }#T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row2_col1{
#             background-color:  #2383ba;
#             color:  #000000;
#         }#T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row2_col3{
#             background-color:  #a2bcda;
#             color:  #000000;
#         }#T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row2_col4{
#             background-color:  #4e9ac6;
#             color:  #000000;
#         }#T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row3_col0{
#             background-color:  #045687;
#             color:  #f1f1f1;
#         }#T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row3_col1{
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }#T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row3_col2{
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }#T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row3_col4{
#             background-color:  #4496c3;
#             color:  #000000;
#         }#T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row4_col0{
#             background-color:  #328dbf;
#             color:  #000000;
#         }#T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row4_col1{
#             background-color:  #9fbad9;
#             color:  #000000;
#         }#T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row4_col2{
#             background-color:  #3b92c1;
#             color:  #000000;
#         }#T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row4_col3{
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }</style><table id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total_Sent</th>        <th class="col_heading level0 col1" >Sent_On_Date</th>        <th class="col_heading level0 col2" >Proceed_In_24_Hr</th>        <th class="col_heading level0 col3" >Total_Positive</th>        <th class="col_heading level0 col4" >New_Positive</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7level0_row0" class="row_heading level0 row0" >Total_Sent</th>
#                         <td id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row0_col1" class="data row0 col1" >0.661474</td>
#                         <td id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row0_col2" class="data row0 col2" >0.773284</td>
#                         <td id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row0_col3" class="data row0 col3" >0.962919</td>
#                         <td id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row0_col4" class="data row0 col4" >0.876228</td>
#             </tr>
#             <tr>
#                         <th id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7level0_row1" class="row_heading level0 row1" >Sent_On_Date</th>
#                         <td id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row1_col0" class="data row1 col0" >0.661474</td>
#                         <td id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row1_col2" class="data row1 col2" >0.889444</td>
#                         <td id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row1_col3" class="data row1 col3" >0.693902</td>
#                         <td id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row1_col4" class="data row1 col4" >0.794989</td>
#             </tr>
#             <tr>
#                         <th id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7level0_row2" class="row_heading level0 row2" >Proceed_In_24_Hr</th>
#                         <td id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row2_col0" class="data row2 col0" >0.773284</td>
#                         <td id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row2_col1" class="data row2 col1" >0.889444</td>
#                         <td id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row2_col3" class="data row2 col3" >0.811190</td>
#                         <td id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row2_col4" class="data row2 col4" >0.912727</td>
#             </tr>
#             <tr>
#                         <th id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7level0_row3" class="row_heading level0 row3" >Total_Positive</th>
#                         <td id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row3_col0" class="data row3 col0" >0.962919</td>
#                         <td id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row3_col1" class="data row3 col1" >0.693902</td>
#                         <td id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row3_col2" class="data row3 col2" >0.811190</td>
#                         <td id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row3_col4" class="data row3 col4" >0.917129</td>
#             </tr>
#             <tr>
#                         <th id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7level0_row4" class="row_heading level0 row4" >New_Positive</th>
#                         <td id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row4_col0" class="data row4 col0" >0.876228</td>
#                         <td id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row4_col1" class="data row4 col1" >0.794989</td>
#                         <td id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row4_col2" class="data row4 col2" >0.912727</td>
#                         <td id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row4_col3" class="data row4 col3" >0.917129</td>
#                         <td id="T_87a039da_09fd_11eb_8a89_507b9d5f0fd7row4_col4" class="data row4 col4" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
model_multi.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           New_Positive   R-squared:                       0.905
# Model:                            OLS   Adj. R-squared:                  0.901
# Method:                 Least Squares   F-statistic:                     198.0
# Date:                Fri, 09 Oct 2020   Prob (F-statistic):           1.06e-31
# Time:                        12:33:27   Log-Likelihood:                -530.00
# No. Observations:                  66   AIC:                             1068.
# Df Residuals:                      62   BIC:                             1077.
# Df Model:                           3
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept        -3244.6127    295.996    -10.962      0.000   -3836.301   -2652.925
# Total_Sent           0.0014      0.000      6.827      0.000       0.001       0.002
# Sent_On_Date        -0.0042      0.013     -0.319      0.751      -0.031       0.022
# Proceed_In_24_Hr     0.1124      0.019      6.018      0.000       0.075       0.150
# ==============================================================================
# Omnibus:                        5.515   Durbin-Watson:                   1.096
# Prob(Omnibus):                  0.063   Jarque-Bera (JB):                5.468
# Skew:                          -0.392   Prob(JB):                       0.0649
# Kurtosis:                       4.172   Cond. No.                     6.47e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.47e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
features.columns
# Out:
# Index(['Total_Sent', 'Sent_On_Date', 'Proceed_In_24_Hr', 'Total_Positive'], dtype='object')

# %% [markdown]
# ### feature selection

# %%
# Defining a function to evaluate a model
def evaluateModel(model):
    print("RSS = ", ((test_report.New_Positive - model.predict())**2).sum())
    print("R2 = ", model.rsquared)

# %%
# for Total_Sent
model_Total_Sent  = sm.ols('New_Positive ~ Total_Sent',test_report).fit()
evaluateModel(model_Total_Sent)
# Out:
# RSS =  89639845.57674588
# R2 =  0.7677760295457687

# %%
# for Sent_On_Date
model_Sent_On_Date  = sm.ols('New_Positive ~ Sent_On_Date',test_report).fit()
evaluateModel(model_Sent_On_Date)
# Out:
# RSS =  142047315.07355666
# R2 =  0.6320074930238184

# %%
# for Proceed_In_24_Hr
model_Proceed_In_24_Hr  = sm.ols('New_Positive ~ Proceed_In_24_Hr',test_report).fit()
evaluateModel(model_Proceed_In_24_Hr)
# Out:
# RSS =  64435608.95868143
# R2 =  0.8330709646503115

# %%
# for Total_Positive
model_Total_Positive  = sm.ols('New_Positive ~ Total_Positive',test_report).fit()
evaluateModel(model_Total_Positive)
# Out:
# RSS =  61326207.399666965
# R2 =  0.8411262839240679

# %%
#for total positive processed in 24 
model_Total_Positive_processed24  = sm.ols('New_Positive ~ Total_Positive + Proceed_In_24_Hr',test_report).fit()
evaluateModel(model_Total_Positive_processed24)
# Out:
# RSS =  29178592.420444813
# R2 =  0.9244089663414231

# %%
#for total positive processed in 24 Total_Sent
model_Totalpos_processed24sent  = sm.ols('New_Positive ~ Total_Positive + Proceed_In_24_Hr + Total_Sent',test_report).fit()
evaluateModel(model_Totalpos_processed24sent)
# Out:
# RSS =  29129761.3589204
# R2 =  0.9245354697162976

# %%
#for total positive processed in 24 sendondate
model_Totalpos_processed24_ondate  = sm.ols('New_Positive ~ Total_Positive + Proceed_In_24_Hr + Sent_On_Date',test_report).fit()
evaluateModel(model_Totalpos_processed24_ondate)
# Out:
# RSS =  29166318.162368193
# R2 =  0.9244407644433341

# %%
#while combining all
model_all = sm.ols('New_Positive ~ Total_Positive + Proceed_In_24_Hr + Sent_On_Date + Total_Sent ',test_report).fit()
evaluateModel(model_all)
# Out:
# RSS =  29117794.563421793
# R2 =  0.9245664712954104

# %% [markdown]
# ### visualizing

# %%
from mpl_toolkits import mplot3d

# %%
model_Total_Positive_processed24  = sm.ols('New_Positive ~ Total_Positive + Proceed_In_24_Hr',test_report)
resuts_formula = model_Total_Positive_processed24.fit()
x_surf,y_surf = np.meshgrid(np.linspace(test_report.Total_Positive.min(),test_report.Total_Positive.max(),100),np.linspace(test_report.Proceed_In_24_Hr.min(),test_report.Proceed_In_24_Hr.max(),100))
onlyX = pd.DataFrame({'Total_Positive':x_surf.ravel(),'Proceed_In_24_Hr':y_surf.ravel()})
fittedY = resuts_formula.predict(exog = onlyX)
fittedY = np.array(fittedY)

# %%
from mpl_toolkits.mplot3d import Axes3D


plt.style.use('default')

fig = plt.figure(figsize=(15,8))


ax1 = fig.add_subplot(131, projection='3d')
ax2 = fig.add_subplot(132, projection='3d')
ax3 = fig.add_subplot(133, projection='3d')

axes = [ax1, ax2, ax3]
for ax in axes:
    ax.plot(test_report.Total_Positive, test_report.Proceed_In_24_Hr, test_report.New_Positive, color='k', zorder=15, linestyle='none', marker='o', alpha=0.5)
    #ax.scatter(test_report['Total_Positive'], test_report['Proceed_In_24_Hr'],c='red',marker='o',alpha=0.5);
    ax.plot_surface(x_surf,y_surf,fittedY.reshape(x_surf.shape),color='None',alpha=0.3)
    ax.set_xlabel('\n Total Positive',fontsize=12)
    ax.set_ylabel('\n Processed in 24 hour',fontsize=12)
    ax.set_zlabel('New positive',fontsize=12)
    ax.locator_params(nbins=4, axis='x')
    ax.locator_params(nbins=5, axis='x')
ax1.view_init(elev=28, azim=120)
ax2.view_init(elev=4, azim=114)
ax3.view_init(elev=60, azim=165)


fig.tight_layout()
fig.savefig('results/multilinearregression.png')
# for ii in np.arange(0, 360, 1):
#     ax1.view_init(elev=32, azim=ii)
#     fig.savefig('gif_image%d.png' % ii)

# %%
# import pyglet
# animation = pyglet.image.load_animation('results/modelmult.gif')
# animSprite = pyglet.sprite.Sprite(animation)
 
 
# w = animSprite.width
# h = animSprite.height
 
# window = pyglet.window.Window(width=w, height=h)
 
# r,g,b,alpha = 0.5,0.5,0.8,0.5
 
 
# pyglet.gl.glClearColor(r,g,b,alpha)
 
# @window.event
# def on_draw():
#     window.clear()
#     animSprite.draw()
 
 
 
# pyglet.app.run()

# %%
train = pd.DataFrame(x_train)
train['New_Positive'] = y_train
model = sm.ols('New_Positive ~ Total_Positive + Proceed_In_24_Hr + Sent_On_Date + Total_Sent ',train).fit()

# %%
predict = model.predict(x_test)

# %%
model.rsquared
# Out:
# 0.9674369898147808

# %%
error = metrics.mean_squared_error(y_test,predict)
print('root mean squared error : ',np.sqrt(error))
r2_Score = metrics.r2_score(y_test,predict)
print("r2 score : ",r2_Score)
# Out:
# root mean squared error :  1145.060421825271
# r2 score :  0.6737050697518528

# %%
test = test_report[['Total_Sent','Sent_On_Date','Proceed_In_24_Hr','Total_Positive']].tail(1)
test
# Out:
#     Total_Sent  Sent_On_Date  Proceed_In_24_Hr  Total_Positive
# 65     3402903         62661             62661          258850

# %%
X_train_scaled.shape
# Out:
# (46, 4)

# %%
test_predicted = model.predict(test)

# %%
actual = test_report['New_Positive'].tail(1).values
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted))
# Out:
# new test positives on ['08/10/2020']
# actual :     [5445]
# predicted :  9647

# %% [markdown]
# ## Using MLPRegressor

# %%
from sklearn.neural_network import MLPRegressor

# %%
model_mlp = MLPRegressor(solver='sgd')
x_train,x_test,y_train,y_test = train_test_split(features,label,test_size = 0.3,random_state=42)

# %%
model_mlp.fit(x_train,y_train)
# Out:
# C:\Users\Shoukkiya_Ashraf\miniconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1342: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#              beta_2=0.999, early_stopping=False, epsilon=1e-08,
#              hidden_layer_sizes=(100,), learning_rate='constant',
#              learning_rate_init=0.001, max_fun=15000, max_iter=200,
#              momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#              power_t=0.5, random_state=None, shuffle=True, solver='sgd',
#              tol=0.0001, validation_fraction=0.1, verbose=False,
#              warm_start=False)

# %%
x_train
# Out:
#     Total_Sent  Sent_On_Date  Proceed_In_24_Hr  Total_Positive
# 6      1000988         16780             20583           35515
# 28     1697042         11839             14137           76525
# 4       963632         26981             27714           33120
# 48     2450599         23225             25848          138631
# 36     1978316         45022             45949           95917
# 19      142258         37583             36353           58262
# 56     2862094         57775             52755          187276
# 59     3049791         64257             63175          213499
# 58     2985534         59800             59157          204241
# 50     2545385         52628             51200          148132
# 31     1792330         36762             36310           82104
# 44     2287796         42657             45730          122214
# 64     3340242         76551             73816          253405
# 15     1276358         36282             36291           50231
# 27     1685203         15424             18027           75385
# 26     1669779         26146             27908           73855
# 24     1608013         82221             41860           69304
# 47     2427374         42763             41630          135721
# 11     1154365         33430             32108           42885
# 32     1832275         39945             40162           82104
# 61     3164072         59194             58727          229886
# 46     2384611         48394             47452          131025
# 37     2018921         40605             40014           99266
# 29     1724658         27616             23850           78072
# 43     2245139         46281             46162          117863
# 49     2492757         42158             38574          142756
# 1       884056         25096             25096           29151
# 21     1484907         38527             34344           61879
# 2       908355         24299             25205           30449
# 53     2717040         59610             58799          167939
# 39     2099549         45748             43954          105139
# 35     1933294         41591             37264           92515
# 52     2657430         57071             56057          160933
# 23     1525792             0             37873           66761
# 55     2804319         33585             36027          179922
# 10     1120935         33213             31738           41277
# 22     1525792         40885             40352           64355
# 18     1386775         37704             37027           56354
# 57     2925734         63640             63682          196106
# 38     2053801         34880             35056          102254
# 20     1446380         23822             26186           59504
# 60     3104878         55087             54563          221333
# 7      1027433         26445             21625           36932
# 42     2198858         46273             41054          114033
# 14     1240076         34317             29265           47898
# 51     2600359         54974             54989          148132

# %%
x_test
# Out:
#     Total_Sent  Sent_On_Date  Proceed_In_24_Hr  Total_Positive
# 54     2770734         53694             54493          175384
# 62     3198423         34351             38696          234928
# 0       858960         24745             20087           27956
# 45     2336217         48421             47723          126381
# 5       984208         20576             22745           34331
# 63     3263691         65268             60494          242799
# 16     1312992         36634             37010           52199
# 12     1182727         28362             30123           44415
# 65     3402903         62661             62661          258850
# 30     1755568         30910             30342           79625
# 33     1872496         40221             41392           84759
# 9      1087722         31362             31270           39708
# 41     2152585         19790             22279          110818
# 13     1205759         23032             26150           46140
# 34     1891703         19207             20215           89489
# 25     1643633         35620             34988           71701
# 3       936651         28296             27608           31700
# 17     1349071         36079             35825           54182
# 40     2132795         33246             34786          108278
# 8      1056360         28927             28644           38144

# %%
predict_mlp = model_mlp.predict(x_test)

# %%
error = metrics.mean_squared_error(y_test,predict_mlp)
print('root mean squared error : ',np.sqrt(error))
r2_Score = metrics.r2_score(y_test,predict_mlp)
print("r2 score : ",r2_Score)
# Out:
# root mean squared error :  7.626200589696975e+21
# r2 score :  -1.4473380068713399e+37

# %%
test
# Out:
#     Total_Sent  Sent_On_Date  Proceed_In_24_Hr  Total_Positive
# 65     3402903         62661             62661          258850

# %%
test_predicted = model_mlp.predict(test)
actual = test_report['New_Positive'].tail(1).values
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted))
# Out:
# new test positives on ['08/10/2020']
# actual :     [5445]
# predicted :  -7626200589696974716928

# %%
test_predicted
# Out:
# array([-7.62620059e+21])

# %% [markdown]
# ## Using  DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model_tree = DecisionTreeRegressor()

# %%
model_tree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
predict_tree = model_tree.predict(x_test)

# %%
error = metrics.mean_squared_error(y_test,predict_tree)
print('root mean squared error : ',np.sqrt(error))
r2_Score = metrics.r2_score(y_test,predict_tree)
print("r2 score : ",r2_Score)
# Out:
# root mean squared error :  1034.5127355426805
# r2 score :  0.7336668649111403

# %%
model_tree.score(x_test,y_test)
# Out:
# 0.7336668649111403

# %%
test_predicted_tree = model_tree.predict(np.array(test).reshape(1,-1))
actual = test_report.iloc[:,5].tail(1).values
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted_tree))
# Out:
# new test positives on ['08/10/2020']
# actual :     [5445]
# predicted :  8830

# %% [markdown]
# # KNeighborsRegressor

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
model_knn = KNeighborsRegressor()

# %%
model_knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                     weights='uniform')

# %%
predict_knn = model_knn.predict(x_test)

# %%
error = metrics.mean_squared_error(y_test,predict_knn)
print('root mean squared error : ',np.sqrt(error))
r2_Score = metrics.r2_score(y_test,predict_knn)
print("r2 score : ",r2_Score)
# Out:
# root mean squared error :  1242.0417835161588
# r2 score :  0.616093088591628

# %%
model_knn.score(x_test,y_test)
# Out:
# 0.616093088591628

# %%
test_predicted = model_knn.predict(np.array(test).reshape(1,-1))

print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted))
# Out:
# new test positives on ['08/10/2020']
# actual :     [5445]
# predicted :  8877

# %%
print('prediction by Multilinearregression')
test_predicted = model.predict(test)
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted))
print('--------------------------------------------------------')

print('prediction by KNNregressor')
test_predicted = model_knn.predict(np.array(test).reshape(1,-1))
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted))
print('--------------------------------------------------------')

print('prediction by Decision tree regressor')
test_predicted_tree = model_tree.predict(np.array(test).reshape(1,-1))
actual = test_report.iloc[:,5].tail(1).values
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted_tree))
# Out:
# prediction by Multilinearregression
# new test positives on ['08/10/2020']
# actual :     [5445]
# predicted :  9647
# --------------------------------------------------------
# prediction by KNNregressor
# new test positives on ['08/10/2020']
# actual :     [5445]
# predicted :  8877
# --------------------------------------------------------
# prediction by Decision tree regressor
# new test positives on ['08/10/2020']
# actual :     [5445]
# predicted :  8830

# %% [markdown]
# # Trying with xgboost

# %%
import xgboost as xgb

# %%
model_xgb = xgb.XGBRFRegressor()

# %%
model_xgb.fit(x_train,y_train)
# Out:
# [13:53:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRFRegressor(base_score=0.5, colsample_bylevel=1, colsample_bynode=0.8,
#                colsample_bytree=1, gamma=0, learning_rate=1, max_delta_step=0,
#                max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#                n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#                reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#                silent=None, subsample=0.8, verbosity=1)

# %%
predict_xgb = model_xgb.predict(x_test)

# %%
predict_xgb
# Out:
# array([6759.33  , 4354.531 , 1440.0732, 4049.0027, 1440.0732, 6888.8394,
#        2009.2128, 1669.2444, 6888.8394, 1787.0847, 2949.0398, 1669.2444,
#        2670.3096, 1440.0732, 2670.3096, 2009.2128, 1499.4789, 2009.2128,
#        2934.6702, 1669.2444], dtype=float32)

# %%
y_test
# Out:
#     New_Positive
# 54          7445
# 62          5042
# 0           1083
# 45          4167
# 5           1211
# 63          7871
# 16          1968
# 12          1530
# 65          5445
# 30          1553
# 33          3082
# 9           1564
# 41          2540
# 13          1725
# 34          1648
# 25          2397
# 3           1251
# 17          1983
# 40          3139
# 8           1212

# %%
error = metrics.mean_squared_error(y_test,predict_xgb)
print('mean squared error : ',error)
r2_Score = metrics.r2_score(y_test,predict_xgb)
print("r2 score : ",r2_Score)
# Out:
# mean squared error :  294875.87893742917
# r2 score :  0.9266174554763134

# %%
print('prediction by XGboost regressor')
test_predicted_xgb = model_xgb.predict(test)
actual = test_report.iloc[:,5].tail(1).values
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted_xgb))
# Out:
# prediction by XGboost regressor
# new test positives on ['08/10/2020']
# actual :     [5445]
# predicted :  6888

# %%
#current best 
print('prediction by Multilinearregression')
test_predicted = model.predict(test)
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted))
print('--------------------------------------------------------')

print('prediction by KNNregressor')
test_predicted = model_knn.predict(np.array(test).reshape(1,-1))
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted))
print('--------------------------------------------------------')

print('prediction by Decision tree regressor')
test_predicted_tree = model_tree.predict(np.array(test).reshape(1,-1))
actual = test_report.iloc[:,5].tail(1).values
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted_tree))
print('--------------------------------------------------------')


print('prediction by XGboost regressor')
test_predicted_xgb = model_xgb.predict(test)
actual = test_report.iloc[:,5].tail(1).values
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted_xgb))
# Out:
# prediction by Multilinearregression
# new test positives on ['08/10/2020']
# actual :     [5445]
# predicted :  9647
# --------------------------------------------------------
# prediction by KNNregressor
# new test positives on ['08/10/2020']
# actual :     [5445]
# predicted :  8877
# --------------------------------------------------------
# prediction by Decision tree regressor
# new test positives on ['08/10/2020']
# actual :     [5445]
# predicted :  8830
# --------------------------------------------------------
# prediction by XGboost regressor
# new test positives on ['08/10/2020']
# actual :     [5445]
# predicted :  6888

# %%
#xgboost
model_xgb.fit(x_train,y_train)
pred_all = model_xgb.predict(x_test)
print(model_xgb.score(x_train,y_train))
error = metrics.mean_squared_error(y_test,pred_all)
print('root mean squared error : ',np.sqrt(error))
r2_Score = metrics.r2_score(y_test,pred_all)
print("r2 score : ",r2_Score)
# Out:
# [13:53:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 0.8786952772065209
# root mean squared error :  543.0247498387428
# r2 score :  0.9266174554763134

# %%
#current best traing with all features
modeld = []
dated  = np.array(test_report['Date'].tail(1))
actuald = []
predictedd = []


print('prediction by Multilinearregression')
test_predicted = model.predict(test)
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted))

modeld.append('Multilinearregression')
actuald.append(int(actual))
predictedd.append(int(test_predicted))
print('--------------------------------------------------------')

print('prediction by KNNregressor')
test_predicted = model_knn.predict(np.array(test).reshape(1,-1))
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted))

modeld.append('KNNregression')
actuald.append(int(actual))
predictedd.append(int(test_predicted))
print('--------------------------------------------------------')

print('prediction by Decision tree regressor')
test_predicted_tree = model_tree.predict(np.array(test).reshape(1,-1))
actual = test_report.iloc[:,5].tail(1).values
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted_tree))

modeld.append('Decision tree regression')
actuald.append(int(actual))
predictedd.append(int(test_predicted_tree))
print('--------------------------------------------------------')


print('prediction by XGboost regressor')
test_predicted_xgb = model_xgb.predict(test)
actual = test_report.iloc[:,5].tail(1).values
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted_xgb))

modeld.append('XGboost regression')
actuald.append(int(actual))
predictedd.append(int(test_predicted_xgb))
# Out:
# prediction by Multilinearregression
# new test positives on ['08/10/2020']
# actual :     [5445]
# predicted :  9647
# --------------------------------------------------------
# prediction by KNNregressor
# new test positives on ['08/10/2020']
# actual :     [5445]
# predicted :  8877
# --------------------------------------------------------
# prediction by Decision tree regressor
# new test positives on ['08/10/2020']
# actual :     [5445]
# predicted :  8830
# --------------------------------------------------------
# prediction by XGboost regressor
# new test positives on ['08/10/2020']
# actual :     [5445]
# predicted :  6888

# %%
date = '08-10-2020'
data = {'Date {0}'.format(date):'','model name':modeld,'Actual New_positive':actuald,'Predicted':predictedd}

# %%
report_df = pd.DataFrame(data)
date = str(np.array(test_report['Date'].tail(1)))
date = date.replace('[\'',' ')
date = date.replace('\']',' ')
report_df.style.set_caption('Prediction by various models on {0}'.format(date))
# Out:
# <style  type="text/css" >
# </style><table id="T_c09f6aae_0a08_11eb_8bdb_507b9d5f0fd7" ><caption>Prediction by various models on  08/10/2020 </caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Date 08-10-2020</th>        <th class="col_heading level0 col1" >model name</th>        <th class="col_heading level0 col2" >Actual New_positive</th>        <th class="col_heading level0 col3" >Predicted</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c09f6aae_0a08_11eb_8bdb_507b9d5f0fd7level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c09f6aae_0a08_11eb_8bdb_507b9d5f0fd7row0_col0" class="data row0 col0" ></td>
#                         <td id="T_c09f6aae_0a08_11eb_8bdb_507b9d5f0fd7row0_col1" class="data row0 col1" >Multilinearregression</td>
#                         <td id="T_c09f6aae_0a08_11eb_8bdb_507b9d5f0fd7row0_col2" class="data row0 col2" >5445</td>
#                         <td id="T_c09f6aae_0a08_11eb_8bdb_507b9d5f0fd7row0_col3" class="data row0 col3" >9647</td>
#             </tr>
#             <tr>
#                         <th id="T_c09f6aae_0a08_11eb_8bdb_507b9d5f0fd7level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c09f6aae_0a08_11eb_8bdb_507b9d5f0fd7row1_col0" class="data row1 col0" ></td>
#                         <td id="T_c09f6aae_0a08_11eb_8bdb_507b9d5f0fd7row1_col1" class="data row1 col1" >KNNregression</td>
#                         <td id="T_c09f6aae_0a08_11eb_8bdb_507b9d5f0fd7row1_col2" class="data row1 col2" >5445</td>
#                         <td id="T_c09f6aae_0a08_11eb_8bdb_507b9d5f0fd7row1_col3" class="data row1 col3" >8877</td>
#             </tr>
#             <tr>
#                         <th id="T_c09f6aae_0a08_11eb_8bdb_507b9d5f0fd7level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c09f6aae_0a08_11eb_8bdb_507b9d5f0fd7row2_col0" class="data row2 col0" ></td>
#                         <td id="T_c09f6aae_0a08_11eb_8bdb_507b9d5f0fd7row2_col1" class="data row2 col1" >Decision tree regression</td>
#                         <td id="T_c09f6aae_0a08_11eb_8bdb_507b9d5f0fd7row2_col2" class="data row2 col2" >5445</td>
#                         <td id="T_c09f6aae_0a08_11eb_8bdb_507b9d5f0fd7row2_col3" class="data row2 col3" >8830</td>
#             </tr>
#             <tr>
#                         <th id="T_c09f6aae_0a08_11eb_8bdb_507b9d5f0fd7level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c09f6aae_0a08_11eb_8bdb_507b9d5f0fd7row3_col0" class="data row3 col0" ></td>
#                         <td id="T_c09f6aae_0a08_11eb_8bdb_507b9d5f0fd7row3_col1" class="data row3 col1" >XGboost regression</td>
#                         <td id="T_c09f6aae_0a08_11eb_8bdb_507b9d5f0fd7row3_col2" class="data row3 col2" >5445</td>
#                         <td id="T_c09f6aae_0a08_11eb_8bdb_507b9d5f0fd7row3_col3" class="data row3 col3" >6888</td>
#             </tr>
#     </tbody></table>

# %%
output='{0}'.format(report_df)
from PIL import Image, ImageDraw, ImageFont

img = Image.new('RGB', (800, 250), color = (73, 109, 137))

d = ImageDraw.Draw(img)

d.text((100,100),output,fill=(255, 255, 0))

img.save('results/models.png')

# %%
test_report.columns
# Out:
# Index(['Date', 'Total_Sent', 'Sent_On_Date', 'Proceed_In_24_Hr',
#        'Total_Positive', 'New_Positive'],
#       dtype='object')

# %%
# total_snt = int(test_report['Total_Sent'].tail(1).values)
# total_snt

# %%
#calculating total processed
Proceed_In_24_Hr = test_report['Proceed_In_24_Hr'].values

# %%
# total_processed = 0
# for i in Proceed_In_24_Hr:
#     total_processed = total_processed + i
# unprocessed = total_snt-total_processed
# total_postive = int(test_report['Total_Positive'].tail(1).values)
# total_negative = total_processed - total_postive
# print('total processed until {0} :'.format(test_report['Date'].tail(1).values),total_processed,'\ntotal_unprocessed until {0} :'.format(test_report['Date'].tail(1).values),unprocessed,'\ntotal_positive until {0} :'.format(test_report['Date'].tail(1).values),total_postive,'\ntotal_negtive until {0} :'.format(test_report['Date'].tail(1).values),total_negative)

# %%
# #calculating the percentages :
# total = unprocessed + total_postive + total_negative
# unprocessed_perc = (unprocessed/total)*100
# positive_perc = (total_postive/total)*100
# negtive_per = (total_negative/total)*100
# perc = [unprocessed_perc,positive_perc,negtive_per]
# perc

# %%
# fig_pie , ax_pie = plt.subplots(figsize=(20,15))

# #setting the theme
# plt.rcParams['font.sans-serif'] = 'Arial'
# plt.rcParams['font.family'] = 'sans-serif'
# plt.rcParams['text.color'] = '#909090'
# plt.rcParams['xtick.color'] = '#909090'
# plt.rcParams['ytick.color'] = '#909090'
# plt.rcParams['axes.labelcolor'] = '#909090'
# plt.rcParams['font.size'] = 24

# #setting label names and percentages
# ax_pie.set_title('\nVisualizing test reports processed v/s unprocessed\n\n',fontsize='xx-large')
# labels = ['\n\n\n\n\n    Unprocessed','Processed +ve','Processed -ve']
# explode=(0.05,0,0)
# ax_pie.pie(perc,explode=explode,labels=labels, autopct='%1.0f%%', 
#        shadow=False,colors = ['#5ADAE0','#367DB5','#1410B0'], startangle=0,   
#        pctdistance=1.2,labeldistance=1.4)
# ax_pie.axis('equal')
# ax_pie.legend(frameon=False, bbox_to_anchor=(1.5,0.8))
# fig_pie.savefig('reports/processed_unprocessed.png')

# %%
# total_processed - (total_negative+ total_postive)

# %%
# total_postive = int(test_report['Total_Positive'].tail(1).values)
# total_negative = total_processed - total_postive
# print(total_postive,total_negative)
# perc_processed = [ (total_postive/total_processed)*100 , (total_negative/total_processed)*100]
# perc_processed

# %%
# fig_pie2 , ax_pie = plt.subplots(figsize=(20,15))

# #setting the theme
# plt.rcParams['font.sans-serif'] = 'Arial'
# plt.rcParams['font.family'] = 'sans-serif'
# plt.rcParams['text.color'] = '#909090'
# plt.rcParams['xtick.color'] = '#909090'
# plt.rcParams['ytick.color'] = '#909090'
# plt.rcParams['axes.labelcolor'] = '#909090'
# plt.rcParams['font.size'] = 24

# #setting label names and percentages
# ax_pie.set_title('\nVisualizing test reports positive v/s negtive\n\n',fontsize='xx-large')
# labels = ['Processed +ve','Processed -ve']
# explode=(0.1,0)
# ax_pie.pie(perc_processed,explode=explode,labels=labels, autopct='%1.0f%%', 
#        shadow=False,colors = ['red','#367DB5'], startangle=0,   
#        pctdistance=1.2,labeldistance=1.4)
# ax_pie.axis('equal')
# ax_pie.legend(frameon=False, bbox_to_anchor=(1.5,0.8),loc='lower right',fontsize='xx-large')
# fig_pie2.savefig('reports/positive_negtive.png')
